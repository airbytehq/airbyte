# %% [markdown]
# #### This is a notebook

# %% [markdown]
# ### Authentication part

# %%
from googleads import ad_manager
from googleads import oauth2
import pandas as pd

# %%
credentials = pd.read_csv("sqllab_untitled_query_7_20221006T120602.csv")

# %%
credentials.head()
# Out:
#    ca_key  ca_c_key  ca_a_key  ca_username  ca_password  \
# 0       5         2         4          NaN          NaN
# 1       9         0         4          NaN          NaN
# 2      11         3         4          NaN          NaN
# 3      16         4         4          NaN          NaN
#
#                                          ca_clientid  \
# 0  191712914109-2b5mhu9pv6jblhfl2qmgamnd99gfagbk....
# 1                              115765867776352890972
# 2  252104473782-ki0k7tm9k414jk9lt9ig526kpptaa8df....
# 3  327477212067-0o58fftvg4t7ilkubhkarbtrli5qbg7j....
#
#                        ca_clientsecret  ca_profileid  \
# 0             XQviNztdknGJQQZgH7h9uzJP   22056125484
# 1                                Spiny       4670326
# 2  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       4670326
# 3  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   22688215754
#
#                            ca_developerkey  \
# 0  AIzaSyBbir3fGfi8fBvWqrC6ToBfrZOsREq25do
# 1                                    Spiny
# ...

# %%
import json

# %%
service_key = { "type": "service_account", "project_id": "handy-compass-282417", "private_key_id": "286ba5666f4ba0f018a24155a0ed4c4190df3c54", "private_key": "-----BEGIN PRIVATE KEY-----\\n-----END PRIVATE KEY-----\n", "client_email": "outsider@handy-compass-282417.iam.gserviceaccount.com", "client_id": "103019355925370848853", "auth_uri": "https://accounts.google.com/o/oauth2/auth", "token_uri": "https://oauth2.googleapis.com/token", "auth_provider_x509_cert_url": "https://www.googleapis.com/oauth2/v1/certs", "client_x509_cert_url": "https://www.googleapis.com/robot/v1/metadata/x509/outsider%40handy-compass-282417.iam.gserviceaccount.com" }

# %%
service_key
# Out:
# {'type': 'service_account',
#  'project_id': 'handy-compass-282417',
#  'private_key_id': '286ba5666f4ba0f018a24155a0ed4c4190df3c54',
# ...

# %%
from pathlib import Path
service_key_path = Path('/tmp/service_key.json')

# %%
with open(service_key_path, 'w') as file:
    json.dump(service_key, file)

# %%
application_name = "Spiny"

# %%
oauth2_client = oauth2.GoogleServiceAccountClient(service_key_path, oauth2.GetAPIScope('ad_manager'))

# %%
ad_manager_client = ad_manager.AdManagerClient(oauth2_client, application_name)

# %%
networks = ad_manager_client.GetService('NetworkService').getAllNetworks()

# %%
for network in networks:
   print('Network with network code "%s" and display name "%s" was found. at the following timezone "%s"'% (network['networkCode'], network['displayName'], network["timeZone"]))
# Out:
# Network with network code "22056125484" and display name "Outsider" was found. at the following timezone "America/Chicago"

# %%
ad_manager_client.network_code = networks[0]['networkCode']
ad_manager.timezone = networks[0]['timeZone']

# %%
report_downloader = ad_manager_client.GetDataDownloader(version='v202208')

# %%
def add_dates_ranges(report_job, start_date, end_date):
    """add the start date and the end date to the report job.

    Args:
        report_job (_type_): _description_
        start_date (_type_): _description_
        end_date (_type_): _description_
    """
    if start_date and end_date:
        report_job['reportQuery']['dateRangeType'] = 'CUSTOM_DATE'
        report_job['reportQuery']['startDate'] = start_date
        report_job['reportQuery']['endDate'] = end_date
    else:
        report_job["reportQuery"]["dateRangeType"] = 'YESTERDAY'
    return report_job

# %%
def generate_report_per_hour(start_date, end_date):
    """this generate the report for ad unit per hour.

    Args:
        start_date (_type_): _description_
        end_date (_type_): _description_
    """
    columns = ["TOTAL_INVENTORY_LEVEL_UNFILLED_IMPRESSIONS",
                "TOTAL_LINE_ITEM_LEVEL_IMPRESSIONS",
                "TOTAL_LINE_ITEM_LEVEL_CLICKS",
                "TOTAL_LINE_ITEM_LEVEL_CPM_AND_CPC_REVENUE",
                "TOTAL_LINE_ITEM_LEVEL_WITHOUT_CPD_AVERAGE_ECPM",
                "TOTAL_LINE_ITEM_LEVEL_CTR",
                "TOTAL_CODE_SERVED_COUNT"]
    dimensions = ['AD_UNIT_NAME', 'HOUR', "DATE"]
    report_job = {"reportQuery":{}}
    report_job['reportQuery']['dimensions'] = dimensions
    report_job['reportQuery']['columns'] = columns
    report_job["reportQuery"]["adUnitView"] = 'HIERARCHICAL'
    report_job = add_dates_ranges(report_job, start_date, end_date)
    return report_job

# %%
from datetime import datetime, timedelta

# %%
end_time = datetime.today()
start_time = end_time - timedelta(days=1)

# %%
def convert_time_to_dict(date):
    return {
        'year': date.year,
        'month': date.month,
        'day': date.day
    }

# %%
end_time = convert_time_to_dict(end_time)
start_time = convert_time_to_dict(start_time)

# %%
two_days_ago = convert_time_to_dict(datetime.today() - timedelta(days=2))

# %%
two_days_ago
# Out:
# {'year': 2022, 'month': 10, 'day': 11}

# %%
ad_unit_per_hour_report_job = generate_report_per_hour(two_days_ago, two_days_ago)

# %%
ad_unit_per_hour_report_job
# Out:
# {'reportQuery': {'dimensions': ['AD_UNIT_NAME', 'HOUR', 'DATE'],
#   'columns': ['TOTAL_INVENTORY_LEVEL_UNFILLED_IMPRESSIONS',
#    'TOTAL_LINE_ITEM_LEVEL_IMPRESSIONS',
#    'TOTAL_LINE_ITEM_LEVEL_CLICKS',
#    'TOTAL_LINE_ITEM_LEVEL_CPM_AND_CPC_REVENUE',
#    'TOTAL_LINE_ITEM_LEVEL_WITHOUT_CPD_AVERAGE_ECPM',
#    'TOTAL_LINE_ITEM_LEVEL_CTR',
#    'TOTAL_CODE_SERVED_COUNT'],
#   'adUnitView': 'HIERARCHICAL',
#   'dateRangeType': 'CUSTOM_DATE',
#   'startDate': {'year': 2022, 'month': 10, 'day': 11},
#   'endDate': {'year': 2022, 'month': 10, 'day': 11}}}

# %%
from googleads import errors

# %%
def run_report(report_job):
    """this run the report and return the report id.

    Args:
        report_job (_type_): _description_
    """
    try:
        # Run the report and wait for it to finish.
        report_job_id = report_downloader.WaitForReport(report_job)
    except errors.AdManagerReportError as e:
        print('Failed to generate report. Error was: {}'.format(e))
    return report_job_id

# %%
export_format = 'CSV_DUMP'
import tempfile

# %%
def generate_report(report_job_id):
  report_file = tempfile.NamedTemporaryFile(suffix='.csv.gz', delete=False)
  report_downloader.DownloadReportToFile(report_job_id, export_format, report_file)
  report_file.close()
  print('Report job with id "%s" downloaded to:\n%s' % (report_job_id, report_file.name))
  return report_file.name

# %%
report_job_id = run_report(ad_unit_per_hour_report_job)

# %%
report_file = generate_report(report_job_id)
# Out:
# Report job with id "13236125766" downloaded to:
# /var/folders/vw/wxy_zhb13jq46hkwv_3fs97m0000gn/T/tmpmmtb_ycx.csv.gz

# %%
ad_unit_per_hour_df = pd.read_csv(report_file, compression='gzip', header=0, sep=',', quotechar='"')

# %%
ad_unit_per_hour_df
# Out:
#               Ad unit 1 Ad unit 2  Dimension.HOUR Dimension.DATE  \
# 0           dw-outsider       NaN               0     2022-10-11
# 1           dw-outsider       NaN               1     2022-10-11
# 2           dw-outsider       NaN               2     2022-10-11
# 3           dw-outsider       NaN               3     2022-10-11
# 4           dw-outsider       NaN               4     2022-10-11
# ..                  ...       ...             ...            ...
# 198  smartview-outsider       NaN              19     2022-10-11
# 199  smartview-outsider       NaN              20     2022-10-11
# 200  smartview-outsider       NaN              21     2022-10-11
# 201  smartview-outsider       NaN              22     2022-10-11
# 202  smartview-outsider       NaN              23     2022-10-11
#
#      Ad unit ID 1 Ad unit ID 2  \
# 0     22061670679            -
# 1     22061670679            -
# 2     22061670679            -
# 3     22061670679            -
# ...

# %%
def get_custom_targeting_keys_ids(name:str) -> list:
    all_keys = []
    custom_targeting_service = ad_manager_client.GetService('CustomTargetingService', version='v202208')
    statement_builder = ad_manager.StatementBuilder(version='v202208')
    page_size = ad_manager.SUGGESTED_PAGE_LIMIT
    if name:
        statement_builder = statement_builder.Where("name = :name").WithBindVariable('name', name)
    statement_builder.limit = page_size
   
    total_result_set_size = 0
    while True:
        response = custom_targeting_service.getCustomTargetingKeysByStatement(statement_builder.ToStatement())
        if 'results' in response and len(response['results']):
            all_keys.extend(response['results'])
            statement_builder.offset += statement_builder.limit
        else:
            break
    customs_target_values = get_custom_targeting_values(all_keys)
    return customs_target_values


def get_custom_targeting_values(all_keys: list) -> list:
    """given a list of keys retrieve the custom targeting values

    Args:
        all_keys (list): _description_

    Returns:
        dict: _description_
    """
    targeting_values = list()
    if all_keys:
        statement_builder = ad_manager.StatementBuilder(version='v202208')
        custom_targeting_service = ad_manager_client.GetService('CustomTargetingService', version='v202208')
        statement = statement_builder.Where("customTargetingKeyId IN ({})".format(",".join([str(key['id']) for key in all_keys])))
        while True:
            response = custom_targeting_service.getCustomTargetingValuesByStatement(statement.ToStatement())
            if 'results' in response and len(response['results']):
                for custom_targeting_value in response['results']:
                    custom_targe_dict = {"id": custom_targeting_value['id'], 
                                         "name": custom_targeting_value['name'],
                                         "displayName": custom_targeting_value['displayName'],
                                         "customTargetingKeyId": custom_targeting_value['customTargetingKeyId']}
                    targeting_values.append(custom_targe_dict)
                statement.offset += statement.limit
            else:
                break
    print("found {} custom targeting values".format(len(targeting_values)))
    return targeting_values

# %%
targeting_values = get_custom_targeting_keys_ids("referrer")
# Out:
# found 16 custom targeting values

# %%
targeting_values[3]
# Out:
# {'id': 448229654161,
#  'name': 'pinterest',
#  'displayName': None,
#  'customTargetingKeyId': 12091825}

# %%
def build_report_by_referrer(targeting_values: list, start_date: dict = {}, end_date: dict = {}) -> dict:
    """build a custom traffic source report

    Args:
        targeting_values (list): _description_

    Returns:
        dict: _description_
    """
    targets_ids = [targeting_value['id'] for targeting_value in targeting_values if targeting_value["id"]]
    targets_ids = ", ".join([str(target_id) for target_id in targets_ids])
    report_job = {"reportQuery":{}}
    custom_traffic_source_columns = [
            "TOTAL_LINE_ITEM_LEVEL_CPM_AND_CPC_REVENUE",
            "TOTAL_LINE_ITEM_LEVEL_IMPRESSIONS",
            "TOTAL_LINE_ITEM_LEVEL_CLICKS",
            "TOTAL_LINE_ITEM_LEVEL_WITHOUT_CPD_AVERAGE_ECPM",
            "TOTAL_ACTIVE_VIEW_VIEWABLE_IMPRESSIONS",
            "TOTAL_ACTIVE_VIEW_MEASURABLE_IMPRESSIONS",
            "TOTAL_ACTIVE_VIEW_ELIGIBLE_IMPRESSIONS",
        ]
    dimensions = ['ADVERTISER_NAME', 'CUSTOM_CRITERIA', 'AD_UNIT_ID', "DATE"]
    report_job["reportQuery"]["dimensions"] = dimensions
    report_job["reportQuery"]["columns"] = custom_traffic_source_columns
    report_job["reportQuery"]["adUnitView"] = 'HIERARCHICAL'
    statement_builder = ad_manager.StatementBuilder(version='v202208')
    statement_builder.Where(f"CUSTOM_TARGETING_VALUE_ID IN ({targets_ids})")
    statement_builder.Limit(None).Offset(None)
    report_job["reportQuery"]["statement"] = statement_builder.ToStatement()
    report_job = add_dates_ranges(report_job, start_date, end_date)
    return report_job

# %%
traffic_source_report_by_referrer = build_report_by_referrer(targeting_values, 
                                                             start_date=two_days_ago, 
                                                             end_date=two_days_ago)

# %%
traffic_source_report_by_referrer
# Out:
# {'reportQuery': {'dimensions': ['ADVERTISER_NAME',
#    'CUSTOM_CRITERIA',
#    'AD_UNIT_ID',
#    'DATE'],
#   'columns': ['TOTAL_LINE_ITEM_LEVEL_CPM_AND_CPC_REVENUE',
#    'TOTAL_LINE_ITEM_LEVEL_IMPRESSIONS',
#    'TOTAL_LINE_ITEM_LEVEL_CLICKS',
#    'TOTAL_LINE_ITEM_LEVEL_WITHOUT_CPD_AVERAGE_ECPM'],
#   'adUnitView': 'HIERARCHICAL',
#   'statement': {'query': 'WHERE CUSTOM_TARGETING_VALUE_ID IN (448229654107, 448229654113, 448229654134, 448229654161, 448229654191, 448229654203, 448229826846, 448229826849, 448229826885, 448230297917, 448257513429, 448258036235, 448265353017, 448307979267, 448440595219, 448440595222)',
#    'values': None},
#   'dateRangeType': 'CUSTOM_DATE',
#   'startDate': {'year': 2022, 'month': 10, 'day': 11},
#   'endDate': {'year': 2022, 'month': 10, 'day': 11}}}

# %%
report_by_referrer_job_id = run_report(traffic_source_report_by_referrer)

# %%
report_by_referrer_file = generate_report(report_by_referrer_job_id)
# Out:
# Report job with id "13236085085" downloaded to:
# /var/folders/vw/wxy_zhb13jq46hkwv_3fs97m0000gn/T/tmpajk7bxck.csv.gz

# %%
ad_unit_per_referrer_df  = pd.read_csv(report_by_referrer_file)

# %%
ad_unit_per_referrer_df.head()
# Out:
#   Dimension.ADVERTISER_NAME Dimension.CUSTOM_CRITERIA  Ad unit ID 1  \
# 0                         -           referrer=direct   22061670679
# 1                         -           referrer=direct   22061670679
# 2                         -           referrer=direct   22061670679
# 3                         -           referrer=direct   22061790345
# 4                         -           referrer=direct   22061790345
#
#   Ad unit ID 2 Dimension.DATE  Dimension.ADVERTISER_ID  \
# 0            -     2022-10-11                       -1
# 1  22064007867     2022-10-11                       -1
# 2  22678688948     2022-10-11                       -1
# 3            -     2022-10-11                       -1
# 4  22063951904     2022-10-11                       -1
#
#    Dimension.CUSTOM_TARGETING_VALUE_ID    Ad unit 1     Ad unit 2  \
# 0                         448229654113  dw-outsider           NaN
# 1                         448229654113  dw-outsider  news-article
# ...

# %%
columns_mapping = {
    "AdUnitOne": 'Ad unit 1',
    "AdUnitTwo": 'Ad unit 2',
    "AdUnitThree": 'Ad unit 3',
    "Advertiser": 'Dimension.ADVERTISER_NAME',
    "CreativeSizeDeliveredWidth": 'Dimension.CREATIVE_SIZE_DELIVERED',
    "CreativeSizeDeliveredHeight": 'Dimension.CREATIVE_SIZE_DELIVERED',
    "LineItemType": 'Dimension.LINE_ITEM_TYPE',
    "LineItemName": 'Dimension.LINE_ITEM_NAME',
    "InventoryType": 'Dimension.MOBILE_INVENTORY_TYPE',
    "DeviceCategoryName": 'Dimension.DEVICE_CATEGORY_NAME',
    'BreakdownKey': 'Dimension.CUSTOM_CRITERIA',
    'BreakdownValue': 'Dimension.CUSTOM_CRITERIA',
    "Hour": "Dimension.HOUR",
    'TotalUnmatchedAdRequests': 'Column.TOTAL_UNMATCHED_AD_REQUESTS',
    'TotalResponsesServed': 'Column.TOTAL_RESPONSES_SERVED',
    'TotalActiveViewViewableImpressions': 'Column.TOTAL_ACTIVE_VIEW_VIEWABLE_IMPRESSIONS',
    'TotalActiveViewMeasurableImpressions': 'Column.TOTAL_ACTIVE_VIEW_MEASURABLE_IMPRESSIONS',
    'TotalActiveViewEligibleImpressions': 'Column.TOTAL_ACTIVE_VIEW_ELIGIBLE_IMPRESSIONS',
    'TotalRevenue': 'Column.TOTAL_LINE_ITEM_LEVEL_ALL_REVENUE',
    'TotalCpmAndCpcRevenue': 'Column.TOTAL_LINE_ITEM_LEVEL_CPM_AND_CPC_REVENUE',
    'TotalAdRequests': 'Column.TOTAL_AD_REQUESTS',
    'TotalImpressions': 'Column.TOTAL_LINE_ITEM_LEVEL_IMPRESSIONS',
    "TotalEcpm": 'Column.TOTAL_LINE_ITEM_LEVEL_WITHOUT_CPD_AVERAGE_ECPM',
    "TotalEcp:withCpd": 'Column.TOTAL_LINE_ITEM_LEVEL_WITH_CPD_AVERAGE_ECPM',
    "TotalUnfilledImpressions": 'Column.TOTAL_INVENTORY_LEVEL_UNFILLED_IMPRESSIONS',
    'TotalClicks': 'Column.TOTAL_LINE_ITEM_LEVEL_CLICKS'}
columns_mapping = {v:k for k, v in columns_mapping.items()}

# %%
columns_mapping
# Out:
# {'Ad unit 1': 'AdUnitOne',
#  'Ad unit 2': 'AdUnitTwo',
#  'Ad unit 3': 'AdUnitThree',
#  'Dimension.ADVERTISER_NAME': 'Advertiser',
#  'Dimension.CREATIVE_SIZE_DELIVERED': 'CreativeSizeDeliveredHeight',
#  'Dimension.LINE_ITEM_TYPE': 'LineItemType',
#  'Dimension.LINE_ITEM_NAME': 'LineItemName',
#  'Dimension.MOBILE_INVENTORY_TYPE': 'InventoryType',
#  'Dimension.DEVICE_CATEGORY_NAME': 'DeviceCategoryName',
#  'Dimension.CUSTOM_CRITERIA': 'BreakdownValue',
#  'Dimension.HOUR': 'Hour',
#  'Column.TOTAL_UNMATCHED_AD_REQUESTS': 'TotalUnmatchedAdRequests',
#  'Column.TOTAL_RESPONSES_SERVED': 'TotalResponsesServed',
#  'Column.TOTAL_ACTIVE_VIEW_VIEWABLE_IMPRESSIONS': 'TotalActiveViewViewableImpressions',
#  'Column.TOTAL_ACTIVE_VIEW_MEASURABLE_IMPRESSIONS': 'TotalActiveViewMeasurableImpressions',
#  'Column.TOTAL_ACTIVE_VIEW_ELIGIBLE_IMPRESSIONS': 'TotalActiveViewEligibleImpressions',
#  'Column.TOTAL_LINE_ITEM_LEVEL_ALL_REVENUE': 'TotalRevenue',
# ...

# %%
ad_unit_per_referrer_df = ad_unit_per_referrer_df.rename(columns_mapping, axis="columns").rename({"BreakdownValue": "referrer"}, axis="columns")

# %%
ad_unit_per_referrer_df.head()
# Out:
#   Advertiser         referrer  Ad unit ID 1 Ad unit ID 2 Dimension.DATE  \
# 0          -  referrer=direct   22061670679            -     2022-10-11
# 1          -  referrer=direct   22061670679  22064007867     2022-10-11
# 2          -  referrer=direct   22061670679  22678688948     2022-10-11
# 3          -  referrer=direct   22061790345            -     2022-10-11
# 4          -  referrer=direct   22061790345  22063951904     2022-10-11
#
#    Dimension.ADVERTISER_ID  Dimension.CUSTOM_TARGETING_VALUE_ID    AdUnitOne  \
# 0                       -1                         448229654113  dw-outsider
# 1                       -1                         448229654113  dw-outsider
# 2                       -1                         448229654113  dw-outsider
# 3                       -1                         448229654113  mw-outsider
# 4                       -1                         448229654113  mw-outsider
#
# ...

# %%
ad_unit_per_referrer_df.referrer = ad_unit_per_referrer_df.referrer.str.replace("referrer=", "")

# %%
device_mapping = {"amp": "AMP", "dw": "WEB", "mw": "WEB", "smartview": "WEB"}

# %%
ad_unit_per_referrer_df["ad_unit"] = ad_unit_per_referrer_df["AdUnitOne"].str.split("-").str[0]

# %%
ad_unit_per_referrer_df.head()
# Out:
#   Advertiser referrer  Ad unit ID 1 Ad unit ID 2 Dimension.DATE  \
# 0          -   direct   22061670679            -     2022-10-11
# 1          -   direct   22061670679  22064007867     2022-10-11
# 2          -   direct   22061670679  22678688948     2022-10-11
# 3          -   direct   22061790345            -     2022-10-11
# 4          -   direct   22061790345  22063951904     2022-10-11
#
#    Dimension.ADVERTISER_ID  Dimension.CUSTOM_TARGETING_VALUE_ID    AdUnitOne  \
# 0                       -1                         448229654113  dw-outsider
# 1                       -1                         448229654113  dw-outsider
# 2                       -1                         448229654113  dw-outsider
# 3                       -1                         448229654113  mw-outsider
# 4                       -1                         448229654113  mw-outsider
#
#       AdUnitTwo  TotalCpmAndCpcRevenue  TotalImpressions  TotalClicks  \
# ...

# %% [markdown]
# Add Unit Per hour

# %%
ad_unit_per_referrer_df_group = ad_unit_per_referrer_df.groupby(["ad_unit", "referrer"]).agg(total_cpm_cpc_revenue= ("TotalCpmAndCpcRevenue", "sum"), 
                                                              total_impressions=("TotalImpressions", "sum"), 
                                                              total_average_eCpm=("TotalEcpm", "mean"),
                                                              total_sum_eCpm=("TotalEcpm", "sum"),
                                                              total_clicks=("TotalClicks", "sum"))

# %%
ad_unit_per_referrer_df_group
# Out:
#                     total_cpm_cpc_revenue  total_impressions  \
# ad_unit referrer
# amp     direct                   36957093              13027
#         discover                 18865900               8666
#         facebook                    19639                 63
#         googlenews                  23943                 28
#         newsbreak               167794547             156904
#         other                       37904                 68
#         search                   26858292              33189
#         smartnews                30820164              18956
#         twitter                     22108                228
# dw      amp                         12698                  5
#         direct                    9639869               6335
#         facebook                 61449199              41462
#         newsbreak                 5251142               4061
#         other                    13173470               7949
# ...

# %%
ad_unit_per_hour_df.head()
# Out:
#      Ad unit 1 Ad unit 2  Dimension.HOUR Dimension.DATE  Ad unit ID 1  \
# 0  dw-outsider       NaN               0     2022-10-11   22061670679
# 1  dw-outsider       NaN               1     2022-10-11   22061670679
# 2  dw-outsider       NaN               2     2022-10-11   22061670679
# 3  dw-outsider       NaN               3     2022-10-11   22061670679
# 4  dw-outsider       NaN               4     2022-10-11   22061670679
#
#   Ad unit ID 2  Column.TOTAL_INVENTORY_LEVEL_UNFILLED_IMPRESSIONS  \
# 0            -                                                  7
# 1            -                                                  3
# 2            -                                                  4
# 3            -                                                  7
# 4            -                                                  0
#
#    Column.TOTAL_LINE_ITEM_LEVEL_IMPRESSIONS  \
# 0                                      1442
# 1                                       907
# ...

# %%
ad_unit_per_hour_df["ad_unit"] = ad_unit_per_hour_df["Ad unit 1"].str.split("-").str[0]

# %%
ad_unit_per_hour_df = ad_unit_per_hour_df.rename({"Dimension.HOUR": "hour", "Dimension.DATE": "DATE"}, axis='columns')

# %%
ad_unit_per_hour_df = ad_unit_per_hour_df.rename(columns_mapping, axis="columns")

# %%
ad_unit_per_hour_df.head()
# Out:
#      AdUnitOne AdUnitTwo  hour        DATE  Ad unit ID 1 Ad unit ID 2  \
# 0  dw-outsider       NaN     0  2022-10-11   22061670679            -
# 1  dw-outsider       NaN     1  2022-10-11   22061670679            -
# 2  dw-outsider       NaN     2  2022-10-11   22061670679            -
# 3  dw-outsider       NaN     3  2022-10-11   22061670679            -
# 4  dw-outsider       NaN     4  2022-10-11   22061670679            -
#
#    TotalUnfilledImpressions  TotalImpressions  TotalClicks  \
# 0                         7              1442            1
# 1                         3               907            1
# 2                         4               429            0
# 3                         7               677            2
# 4                         0               867            1
#
#    TotalCpmAndCpcRevenue  TotalEcpm  Column.TOTAL_LINE_ITEM_LEVEL_CTR  \
# 0                1801683    1249434                            0.0007
# ...

# %%
ad_unit_by_referrer_expected = "Ad unit by referrer.csv"
ad_unit_per_hours_expected_path = Path.cwd().joinpath("Ad-unit-per-hours.csv")

# %%
Path.cwd().joinpath(ad_unit_by_referrer_expected).exists()
# Out:
# True

# %%
ad_unit_by_referrer_df_expected = pd.read_csv(Path.cwd().joinpath(ad_unit_by_referrer_expected), thousands=",")

# %%
ad_unit_by_referrer_df_expected['referrer'] = ad_unit_by_referrer_df_expected['Key-values'].str.replace("referrer=", "")

# %%
ad_unit_by_referrer_df_expected["Ad unit"] = ad_unit_by_referrer_df_expected["Ad unit"].str.split("-").str[0]

# %%
ad_unit_by_referrer_df_expected.head()
# Out:
#   Ad unit           Key-values      Date    Ad unit ID  Key-values ID  \
# 0     amp      referrer=direct  10/11/22  2.206395e+10   4.482297e+11
# 1     amp    referrer=discover  10/11/22  2.206395e+10   4.482303e+11
# 2     amp    referrer=facebook  10/11/22  2.206395e+10   4.482298e+11
# 3     amp  referrer=googlenews  10/11/22  2.206395e+10   4.482654e+11
# 4     amp   referrer=newsbreak  10/11/22  2.206395e+10   4.482575e+11
#
#   Total impressions Total clicks Total CPM and CPC revenue ($)  \
# 0            13,027          237                         36.96
# 1             8,666           92                         18.87
# 2                63            0                          0.02
# 3                28            0                          0.02
# 4           156,904        2,277                        167.61
#
#   Total average eCPM ($) Total CTR    referrer
# 0                   2.84     1.82%      direct
# 1                   2.18     1.06%    discover
# ...

# %%
ad_unit_by_referrer_df_expected = ad_unit_by_referrer_df_expected.rename({"Total impressions": "total_impressions",
                                              "Total clicks": "total_clicks",
                                              "Total CPM and CPC revenue ($)": "total_cpm_cpc_revenue",
                                              "Total average eCPM ($)": "total_average_eCpm"}, axis="columns")

# %%
ad_unit_by_referrer_df_group_expected = ad_unit_by_referrer_df_expected.loc[:, ["Ad unit", 
                                        'referrer', 
                                        "total_impressions",
                                        "total_clicks", 
                                        "total_cpm_cpc_revenue", 
                                        "total_average_eCpm", "Date"]].groupby(["Ad unit", "referrer"]).agg(
                                            total_cpm_cpc_revenue=("total_cpm_cpc_revenue", "sum"), 
                                            total_impressions=("total_impressions", "sum"), 
                                            total_average_eCpm=("total_average_eCpm", "mean"),
                                            total_sum_eCpm=("total_average_eCpm", "sum"),
                                        )

# %%
ad_unit_per_referrer_df_group
# Out:
#                     total_cpm_cpc_revenue  total_impressions  \
# ad_unit referrer
# amp     direct                     36.957              13027
#         discover                   18.866               8666
#         facebook                    0.020                 63
#         googlenews                  0.024                 28
#         newsbreak                 167.609             156904
#         other                       0.038                 68
#         search                     26.858              33189
#         smartnews                  30.820              18956
#         twitter                     0.022                228
# dw      amp                         0.013                  5
#         direct                      9.668               6357
#         facebook                   61.503              41481
#         newsbreak                   5.251               4061
#         other                      13.173               7949
# ...

# %%
one_megabyte = 1024 * 1024

# %%
ad_unit_per_referrer_df_group["total_average_eCpm"] = (ad_unit_per_referrer_df_group["total_average_eCpm"]/1e6).round(3)

# %%
ad_unit_per_referrer_df_group["total_cpm_cpc_revenue"] = (ad_unit_per_referrer_df_group["total_cpm_cpc_revenue"]/1e6).round(3)

# %%
ad_unit_per_referrer_df_group["total_sum_eCpm"] = (ad_unit_per_referrer_df_group["total_sum_eCpm"]/1e6).round(3)

# %%
ad_unit_per_referrer_df_group
# Out:
#                     total_cpm_cpc_revenue  total_impressions  \
# ad_unit referrer
# amp     direct                     36.957              13027
#         discover                   18.866               8666
#         facebook                    0.020                 63
#         googlenews                  0.024                 28
#         newsbreak                 167.795             156904
#         other                       0.038                 68
#         search                     26.858              33189
#         smartnews                  30.820              18956
#         twitter                     0.022                228
# dw      amp                         0.013                  5
#         direct                      9.640               6335
#         facebook                   61.449              41462
#         newsbreak                   5.251               4061
#         other                      13.173               7949
# ...

# %%
ad_unit_per_referrer_df_group["revenue_computed"] = (ad_unit_per_referrer_df_group.total_impressions * ad_unit_per_referrer_df_group.total_average_eCpm)/1e3

# %%
ad_unit_per_referrer_df_group
# Out:
#                     total_cpm_cpc_revenue  total_impressions  \
# ad_unit referrer
# amp     direct                     36.957              13027
#         discover                   18.866               8666
#         facebook                    0.020                 63
#         googlenews                  0.024                 28
#         newsbreak                 167.795             156904
#         other                       0.038                 68
#         search                     26.858              33189
#         smartnews                  30.820              18956
#         twitter                     0.022                228
# dw      amp                         0.013                  5
#         direct                      9.640               6335
#         facebook                   61.449              41462
#         newsbreak                   5.251               4061
#         other                      13.173               7949
# ...

# %%
ad_unit_by_referrer_df_group_expected
# Out:
#                    total_cpm_cpc_revenue total_impressions  \
# Ad unit referrer
# amp     direct                     36.96            13,027
#         discover                   18.87             8,666
#         facebook                    0.02                63
#         googlenews                  0.02                28
#         newsbreak                 167.61           156,904
#         other                       0.04                68
#         search                     26.86            33,189
#         smartnews                  30.82            18,956
#         twitter                     0.02               228
# dw      amp                         0.01                 5
#         direct                      9.69             6,367
#         facebook                   61.50            41,481
#         newsbreak                   5.25             4,061
#         other                      13.18             7,951
#         search                     79.03            43,008
# ...

# %%
ad_unit_by_referrer_df_expected
# Out:
#    Ad unit           Key-values      Date    Ad unit ID  Key-values ID  \
# 0      amp      referrer=direct  10/11/22  2.206395e+10   4.482297e+11
# 1      amp    referrer=discover  10/11/22  2.206395e+10   4.482303e+11
# 2      amp    referrer=facebook  10/11/22  2.206395e+10   4.482298e+11
# 3      amp  referrer=googlenews  10/11/22  2.206395e+10   4.482654e+11
# 4      amp   referrer=newsbreak  10/11/22  2.206395e+10   4.482575e+11
# 5      amp       referrer=other  10/11/22  2.206395e+10   4.482297e+11
# 6      amp      referrer=search  10/11/22  2.206395e+10   4.482298e+11
# 7      amp   referrer=smartnews  10/11/22  2.206395e+10   4.482580e+11
# 8      amp     referrer=twitter  10/11/22  2.206395e+10   4.482297e+11
# 9       dw         referrer=amp  10/11/22  2.206167e+10   4.482298e+11
# 10      dw      referrer=direct  10/11/22  2.206167e+10   4.482297e+11
# 11      dw    referrer=facebook  10/11/22  2.206167e+10   4.482298e+11
# ...

# %%
ad_unit_by_referrer_df_group_expected.index.names = ["ad_unit", "referrer"]

# %%
ad_unit_per_referrer_df.to_csv("ad_unit_per_referrer_df.csv", index=False)

# %%
from pandas.testing import assert_series_equal

# %%
assert_series_equal(ad_unit_per_referrer_df_group.total_impressions, ad_unit_by_referrer_df_group_expected.total_impressions,)

# %%
ad_unit_per_referrer_df_group.to_csv("ad-unit-per-referrer-df-group_api.csv")

# %%
ad_unit_by_referrer_df_group_expected

# %% [markdown]
# ### Per hour

# %%
ad_unit_per_hours_expected_df = pd.read_csv(ad_unit_per_hours_expected_path, thousands=",")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [128], line 1
# ----> 1 ad_unit_per_hours_expected_df = pd.read_csv(ad_unit_per_hours_expected_path, thousands=",")
#
# NameError: name 'ad_unit_per_hours_expected_path' is not defined

# %%
ad_unit_per_hours_expected_df["ad_unit"] = ad_unit_per_hours_expected_df["Ad unit"].str.split("-").str[0].map(device_mapping)

# %%
ad_unit_per_hours_expected_df = ad_unit_per_hours_expected_df.dropna(axis="rows")

# %%
ad_unit_per_hours_expected_df
# Out:
#    Hour      Date             Ad unit    Ad unit ID  Total impressions  \
# 0     0  10/10/22        amp-outsider  2.206395e+10              12947
# 1     0  10/10/22         dw-outsider  2.206167e+10               1837
# 2     0  10/10/22         mw-outsider  2.206179e+10               8061
# 3     0  10/10/22  smartview-outsider  2.223497e+10               5132
# 4     1  10/10/22        amp-outsider  2.206395e+10               7799
# ..  ...       ...                 ...           ...                ...
# 91   22  10/10/22  smartview-outsider  2.223497e+10              11579
# 92   23  10/10/22        amp-outsider  2.206395e+10              12989
# 93   23  10/10/22         dw-outsider  2.206167e+10               2311
# 94   23  10/10/22         mw-outsider  2.206179e+10              12258
# 95   23  10/10/22  smartview-outsider  2.223497e+10               7780
#
#     Total clicks  Total CPM and CPC revenue ($)  Total average eCPM ($)  \
# ...

# %%
ad_unit_per_hours_expected_df.groupby(["ad_unit", "Hour"]).sum(numeric_only=True)
# Out:
#                 Ad unit ID  Total impressions  Total clicks  \
# ad_unit Hour
# AMP     0     2.206395e+10              12947           191
#         1     2.206395e+10               7799           122
#         10    2.206395e+10              30763           449
#         11    2.206395e+10              31670           421
#         12    2.206395e+10              28743           413
#         13    2.206395e+10              27998           415
#         14    2.206395e+10              28820           432
#         15    2.206395e+10              29106           488
#         16    2.206395e+10              27940           438
#         17    2.206395e+10              27897           412
#         18    2.206395e+10              29830           480
#         19    2.206395e+10              33500           465
#         2     2.206395e+10               6321            86
#         20    2.206395e+10              32260           400
# ...

# %%
ad_unit_per_hour_df.head()
# Out:
#      AdUnitOne AdUnitTwo  hour        DATE  Ad unit ID 1 Ad unit ID 2  \
# 0  dw-outsider       NaN     0  2022-10-11   22061670679            -
# 1  dw-outsider       NaN     1  2022-10-11   22061670679            -
# 2  dw-outsider       NaN     2  2022-10-11   22061670679            -
# 3  dw-outsider       NaN     3  2022-10-11   22061670679            -
# 4  dw-outsider       NaN     4  2022-10-11   22061670679            -
#
#    TotalUnfilledImpressions  TotalImpressions  TotalClicks  \
# 0                         7              1442            1
# 1                         3               907            1
# 2                         4               429            0
# 3                         7               677            2
# 4                         0               867            1
#
#    TotalCpmAndCpcRevenue  TotalEcpm  Column.TOTAL_LINE_ITEM_LEVEL_CTR  \
# 0                1801683    1249434                            0.0007
# ...

# %%
ad_unit_per_hour_df_group = ad_unit_per_hour_df.groupby(["ad_unit", "hour", "DATE"]).agg(total_cpm_cpc_revenue=("TotalCpmAndCpcRevenue", "sum"), 
                                                                                 total_impressions=("TotalImpressions", "sum"), 
                                                                                 total_average_eCpm=("TotalEcpm", "mean"),
                                                                                 total_sum_eCpm=("TotalEcpm", "sum"),
                                                                                 total_unfilled_impressions=("TotalUnfilledImpressions", "sum"))

# %%
ad_unit_per_hour_df_group.total_cpm_cpc_revenue = (ad_unit_per_hour_df_group.total_cpm_cpc_revenue/1e6).round(3)
ad_unit_per_hour_df_group.total_average_eCpm = (ad_unit_per_hour_df_group.total_average_eCpm/1e6).round(3)
ad_unit_per_hour_df_group.total_sum_eCpm = (ad_unit_per_hour_df_group.total_sum_eCpm/1e6).round(3)

# %%
ad_unit_per_hour_df_group
# Out:
#                            total_cpm_cpc_revenue  total_impressions  \
# ad_unit   hour DATE
# amp       0    2022-10-11                  8.570               8729
#           1    2022-10-11                  9.758               5440
#           2    2022-10-11                  3.798               4065
#           3    2022-10-11                  4.826               3631
#           4    2022-10-11                  9.627               4363
# ...                                          ...                ...
# smartview 19   2022-10-11                 12.666              21386
#           20   2022-10-11                 17.044              27161
#           21   2022-10-11                 16.947              27983
#           22   2022-10-11                 10.910              18525
#           23   2022-10-11                  7.416              10673
#
#                            total_average_eCpm  total_sum_eCpm  \
# ad_unit   hour DATE
# ...

# %%
assert_series_equal(ad_unit_by_referrer_df_expected["Total impressions"], ad_unit_per_hour_df_group.total_impressions)

# %%
ad_unit_per_referrer_df

# %%
ad_unit_per_hour_df_group.to_csv("ad_unit_per_hour_df_group.csv")
ad_unit_per_referrer_df_group.to_csv("ad_unit_per_referrer_df_group.csv")

# %% [markdown]
# tommorow make sure I select the date and not using yesterday and today

# %%
ad_unit_per_hour_df_group.to_csv("ad_unit_per_hour_df_group_api.csv")
